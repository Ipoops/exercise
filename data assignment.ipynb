# %% [markdown]
# # My Jupyter notebook on IBM Watson Studio

# %% [markdown]
# Okonkwo, Ifeanyi Nwakasi
# DATA ENGINEER

# %% [markdown]
# I am interested in data science because it helps to pave a way for understanding the patterns of behaviour of things and people around me. I can build tools to anticipate and optimise the decision patterns in my environment

# %% [markdown]
# The code below shows the sum of two numbers
